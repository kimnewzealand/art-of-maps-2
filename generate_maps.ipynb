# %%
import matplotlib.pyplot as plt
import contextily as ctx
import osmnx as ox
import geopandas as gpd
import geodatasets
import folium

# %%
attr_osmnx="Map data from OpenStreetMap. \n Created using OSMnx"
# reveal.js Solarized colors https://github.com/hakimel/reveal.js/blob/master/css/theme/source/solarized.scss
base03_colour = "#002b36"
base02_colour = "#073642"
base01_colour = "#586e75"
base00_colour = "#657b83"
base0_colour = "#839496"
base1_colour = "#93a1a1"
base2_colour = "#eee8d5"
base3_colour = "#fdf6e3"
yellow_colour = "#b58900"
orange_colour = "#cb4b16"
red_colour = "  #dc322f"
magenta_colour = "#d33682"
violet_colour = "#6c71c4"
blue_colour = " #268bd2"
cyan_colour = " #2aa198"
green_colour = "#859900"

# %%
# Create interative map with geopandas
countries = gpd.read_file(geodatasets.get_path('naturalearth.land'))
countries.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1f6b8195ca2431054b936d4ee8d3425 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1f6b8195ca2431054b936d4ee8d3425&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1f6b8195ca2431054b936d4ee8d3425 = L.map(
#                 &quot;map_c1f6b8195ca2431054b936d4ee8d3425&quot;,
#                 {
#                     center: [-3.1774350000000027, 7.105427357601002e-14],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_c1f6b8195ca2431054b936d4ee8d3425);
#
#
#
#
#
#             var tile_layer_b4a3269320a1c1d7c83473d4b6920cc3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b4a3269320a1c1d7c83473d4b6920cc3.addTo(map_c1f6b8195ca2431054b936d4ee8d3425);
#
#
#             map_c1f6b8195ca2431054b936d4ee8d3425.fitBounds(
#                 [[-90.00000000000003, -180.0], [83.64513000000002, 180.00000000000014]],
#                 {}
#             );
#
#
#         function geo_json_adcdee8943f01f65f1f4de2942925274_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_adcdee8943f01f65f1f4de2942925274_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_adcdee8943f01f65f1f4de2942925274_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_adcdee8943f01f65f1f4de2942925274_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_adcdee8943f01f65f1f4de2942925274_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_adcdee8943f01f65f1f4de2942925274.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_adcdee8943f01f65f1f4de2942925274_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_adcdee8943f01f65f1f4de2942925274 = L.geoJson(null, {
#                 onEachFeature: geo_json_adcdee8943f01f65f1f4de2942925274_onEachFeature,
#
#                 style: geo_json_adcdee8943f01f65f1f4de2942925274_styler,
#                 pointToLayer: geo_json_adcdee8943f01f65f1f4de2942925274_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_adcdee8943f01f65f1f4de2942925274_add (data) {
#             geo_json_adcdee8943f01f65f1f4de2942925274
#                 .addData(data);
#         }
#             geo_json_adcdee8943f01f65f1f4de2942925274_add({&quot;bbox&quot;: [-180.0, -90.00000000000003, 180.00000000000014, 83.64513000000002], &quot;features&quot;: [{&quot;bbox&quot;: [-66.29003089055504, -81.00032683707931, -59.57209469261153, -79.62867929475613], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-59.57209469261153, -80.0401787250963], [-59.86584937197463, -80.54965667106187], [-60.159655727770115, -81.00032683707931], [-62.25539343936708, -80.86317758577667], [-64.4881253729

# %%
# Create a static NZ map using contextily
place = ctx.Place('south island, new zealand',source='https://server.arcgisonline.com/ArcGIS/rest/services/NatGeo_World_Map/MapServer/tile/{z}/{y}/{x}')
base_ax = place.plot() 
attr =  'Tiles &copy; Esri &mdash; National Geographic, Esri, DeLorme, NAVTEQ, UNEP-WCMC, USGS, NASA, ESA, METI, NRCAN, GEBCO, NOAA, iPC'
ctx.add_attribution(ax=base_ax,text=attr)
# Out:
# Text(0.005, 0.005, 'Tiles &copy; Esri &mdash; National Geographic, Esri, DeLorme, NAVTEQ, UNEP-WCMC, USGS, NASA, ESA, METI, NRCAN, GEBCO, NOAA, iPC')

# %%
# Create a colourful static Southland map using contextily
basemap = ctx.providers.CartoDB.Positron
place = ctx.Place('Southland,New Zealand', source='https://tiles.macrostrat.org/carto/{z}/{x}/{y}.png')
base_ax = place.plot() 
attr =  basemap.attribution +' | Geological data: MacroStrat.org (CC-BY)'
ctx.add_attribution(ax=base_ax,text=attr)
# Out:
# Text(0.005, 0.005, '(C) OpenStreetMap contributors (C) CARTO | Geological data: MacroStrat.org (CC-BY)')

# %%
# Create Southland walking trails with matplotlib and osmnx 
place ="Southland, New Zealand"
gdf = ox.geocoder.geocode_to_gdf([place])
G = ox.graph.graph_from_place(place, network_type="walk", simplify=True)
fig, ax = ox.plot.plot_graph(
    G,
    show=False,
    close=False,
    bgcolor=base3_colour,
    edge_color=green_colour,
    edge_linewidth=0.3,
    node_size=0,
)
gdf.plot(ax=ax, fc=base3_colour, ec=None, lw=1, alpha=1, zorder=-1)
plt.title("New Zealand Southland Walking Map",color=base3_colour)
ctx.add_attribution(ax, attr_osmnx)
plt.show()
# Out:
# c:\Users\ddobs\Documents\art-of-maps-2\.venv\Lib\site-packages\osmnx\_overpass.py:267: UserWarning: This area is 26 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)

# %%
# Create Southland walking trails with matplotlib and osmnx with basemap
place ="Southland, New Zealand"
gdf = ox.geocoder.geocode_to_gdf([place])
G = ox.graph.graph_from_place(place, network_type="walk", simplify=True)
fig, ax = ox.plot.plot_graph(
    G,
    show=False,
    close=False,
    bgcolor=base3_colour,
    edge_color=green_colour,
    edge_linewidth=0.3,
    node_size=0,
)
gdf.plot(ax=ax, fc=base3_colour, ec=None, lw=1, alpha=1, zorder=-1)
plt.title("New Zealand Southland Walking Map",color=base3_colour)
ctx.add_basemap(ax)
plt.show()
# Out:
# c:\Users\ddobs\Documents\art-of-maps-2\.venv\Lib\site-packages\osmnx\_overpass.py:267: UserWarning: This area is 26 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[40], line 4
#       2 place ="Southland, New Zealand"
#       3 gdf = ox.geocoder.geocode_to_gdf([place])
# ----> 4 G = ox.graph.graph_from_place(place, network_type="walk", simplify=True)
#       5 fig, ax = ox.plot.plot_graph(
#       6     G,
#       7     show=False,
#    (...)     12     node_size=0,
#      13 )
#      14 gdf.plot(ax=ax, fc=base3_colour, ec=None, lw=1, alpha=1, zorder=-1)
#
# File c:\Users\ddobs\Documents\art-of-maps-2\.venv\Lib\site-packages\osmnx\graph.py:395, in graph_from_place(query, network_type, simplify, retain_all, truncate_by_edge, which_result, custom_filter)
#     392 utils.log(msg, level=lg.INFO)
#     394 # create graph using this polygon(s) geometry
# --> 395 G = graph_from_polygon(
#     396     polygon,
#     397     network_type=network_type,
#     398     simplify=simplify,
#     399     retain_all=retain_all,
#     400     truncate_by_edge=truncate_by_edge,
#     401     custom_filter=custom_filter,
#     402 )
#     404 msg = f"graph_from_place returned graph with {len(G):,} nodes and {len(G.edges):,} edges"
#     405 utils.log(msg, level=lg.INFO)
#
# File c:\Users\ddobs\Documents\art-of-maps-2\.venv\Lib\site-packages\osmnx\graph.py:501, in graph_from_polygon(polygon, network_type, simplify, retain_all, truncate_by_edge, custom_filter)
#     495 G_buff = _create_graph(response_jsons, bidirectional)
#     497 # truncate buffered graph to the buffered polygon and retain_all for
#     498 # now. needed because overpass returns entire ways that also include
#     499 # nodes outside the poly if the way (that is, a way with a single OSM
#     500 # ID) has a node inside the poly at some point.
# --> 501 G_buff = truncate.truncate_graph_polygon(G_buff, poly_buff, truncate_by_edge=truncate_by_edge)
#     503 # keep only the largest weakly connected component if retain_all is False
#     504 if not retain_all:
#
# File c:\Users\ddobs\Documents\art-of-maps-2\.venv\Lib\site-packages\osmnx\truncate.py:154, in truncate_graph_polygon(G, polygon, truncate_by_edge)
#     150     nodes_to_remove = nodes_outside_poly
#     152 # now remove from the graph all those nodes that lie outside the polygon
#     153 # make a copy to not mutate original graph object caller passed in
# --> 154 G = G.copy()
#     155 G.remove_nodes_from(nodes_to_remove)
#     156 msg = f"Removed {len(nodes_to_remove):,} nodes outside polygon"
#
# File c:\Users\ddobs\Documents\art-of-maps-2\.venv\Lib\site-packages\networkx\classes\multigraph.py:1105, in MultiGraph.copy(self, as_view)
#    1103 G.graph.update(self.graph)
#    1104 G.add_nodes_from((n, d.copy()) for n, d in self._node.items())
# -> 1105 G.add_edges_from(
#    1106     (u, v, key, datadict.copy())
#    1107     for u, nbrs in self._adj.items()
#    1108     for v, keydict in nbrs.items()
#    1109     for key, datadict in keydict.items()
#    1110 )
#    1111 return G
#
# File c:\Users\ddobs\Documents\art-of-maps-2\.venv\Lib\site-packages\networkx\classes\multigraph.py:611, in MultiGraph.add_edges_from(self, ebunch_to_add, **attr)
#     609     raise NetworkXError(msg)
#     610 ddd = {}
# --> 611 ddd.update(attr)
#     612 try:
#     613     ddd.update(dd)
#
# KeyboardInterrupt:

# %%
# Create Road map of Utrecht with matplotlib and osmnx 
place ="Utrecht, Netherlands"
gdf = ox.geocoder.geocode_to_gdf([place])
G = ox.graph.graph_from_place(place, network_type="drive", retain_all=True)
fig, ax = ox.plot.plot_graph(
    G,
    show=False,
    close=False,
    bgcolor=base3_colour,
    edge_color=base03_colour,
    edge_linewidth=0.3,
    node_size=0,
)
gdf.plot(ax=ax, fc=base3_colour, ec=None, lw=1, alpha=1, zorder=-1)
plt.title("Utrecht Drive Map",color=base3_colour)
ctx.add_attribution(ax, attr_osmnx)
plt.show()

# %%
# Create Bike map of Utrecht with matplotlib and osmnx 
place ="Utrecht, Netherlands"
gdf = ox.geocoder.geocode_to_gdf([place])
G = ox.graph.graph_from_place(place, network_type="bike", retain_all=True)
fig, ax = ox.plot.plot_graph(
    G,
    show=False,
    close=False,
    bgcolor=base3_colour,
    edge_color=orange_colour,
    edge_linewidth=0.3,
    node_size=0,
)
gdf.plot(ax=ax, fc=base3_colour, ec=None, lw=1, alpha=1, zorder=-1)
plt.title("Utrecht Bike Map", color=base3_colour)
ctx.add_attribution(ax, attr_osmnx)
plt.show()
