# %%
import matplotlib.pyplot as plt
import contextily as ctx
import osmnx as ox
import geopandas as gpd
import geodatasets
import folium

# %%
attr_osmnx="Map data from OpenStreetMap. \n Created using OSMnx"
# reveal.js Solarized colors https://github.com/hakimel/reveal.js/blob/master/css/theme/source/solarized.scss
base03_colour = "#002b36"
base02_colour = "#073642"
base01_colour = "#586e75"
base00_colour = "#657b83"
base0_colour = "#839496"
base1_colour = "#93a1a1"
base2_colour = "#eee8d5"
base3_colour = "#fdf6e3"
yellow_colour = "#b58900"
orange_colour = "#cb4b16"
red_colour = "  #dc322f"
magenta_colour = "#d33682"
violet_colour = "#6c71c4"
blue_colour = " #268bd2"
cyan_colour = " #2aa198"
green_colour = "#859900"

# %%
# Create interative map with geopandas
countries = gpd.read_file(geodatasets.get_path('naturalearth.land'))
countries.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1f6b8195ca2431054b936d4ee8d3425 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1f6b8195ca2431054b936d4ee8d3425&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1f6b8195ca2431054b936d4ee8d3425 = L.map(
#                 &quot;map_c1f6b8195ca2431054b936d4ee8d3425&quot;,
#                 {
#                     center: [-3.1774350000000027, 7.105427357601002e-14],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_c1f6b8195ca2431054b936d4ee8d3425);
#
#
#
#
#
#             var tile_layer_b4a3269320a1c1d7c83473d4b6920cc3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b4a3269320a1c1d7c83473d4b6920cc3.addTo(map_c1f6b8195ca2431054b936d4ee8d3425);
#
#
#             map_c1f6b8195ca2431054b936d4ee8d3425.fitBounds(
#                 [[-90.00000000000003, -180.0], [83.64513000000002, 180.00000000000014]],
#                 {}
#             );
#
#
#         function geo_json_adcdee8943f01f65f1f4de2942925274_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_adcdee8943f01f65f1f4de2942925274_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_adcdee8943f01f65f1f4de2942925274_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_adcdee8943f01f65f1f4de2942925274_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_adcdee8943f01f65f1f4de2942925274_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_adcdee8943f01f65f1f4de2942925274.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_adcdee8943f01f65f1f4de2942925274_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_adcdee8943f01f65f1f4de2942925274 = L.geoJson(null, {
#                 onEachFeature: geo_json_adcdee8943f01f65f1f4de2942925274_onEachFeature,
#
#                 style: geo_json_adcdee8943f01f65f1f4de2942925274_styler,
#                 pointToLayer: geo_json_adcdee8943f01f65f1f4de2942925274_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_adcdee8943f01f65f1f4de2942925274_add (data) {
#             geo_json_adcdee8943f01f65f1f4de2942925274
#                 .addData(data);
#         }
#             geo_json_adcdee8943f01f65f1f4de2942925274_add({&quot;bbox&quot;: [-180.0, -90.00000000000003, 180.00000000000014, 83.64513000000002], &quot;features&quot;: [{&quot;bbox&quot;: [-66.29003089055504, -81.00032683707931, -59.57209469261153, -79.62867929475613], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[-59.57209469261153, -80.0401787250963], [-59.86584937197463, -80.54965667106187], [-60.159655727770115, -81.00032683707931], [-62.25539343936708, -80.86317758577667], [-64.4881253729

# %%
# Create a colourful static Southland map using contextily
lat = -40.9006
long =  174.8860
basemap = ctx.providers.CartoDB.Positron
place = ctx.Place('Southland,New Zealand', source='https://tiles.macrostrat.org/carto/{z}/{x}/{y}.png')
base_ax = place.plot() 
attr =  basemap.attribution +' | Geological data: MacroStrat.org (CC-BY)'
ctx.add_attribution(ax=base_ax,text=attr)
# Out:
# Text(0.005, 0.005, '(C) OpenStreetMap contributors (C) CARTO | Geological data: MacroStrat.org (CC-BY)')

# %%
# Create Southland walking trails with matplotlib and osmnx 
place ="Southland, New Zealand"
gdf = ox.geocoder.geocode_to_gdf([place])
G = ox.graph.graph_from_place(place, network_type="walk", simplify=True)
fig, ax = ox.plot.plot_graph(
    G,
    show=False,
    close=False,
    bgcolor=base3_colour,
    edge_color=green_colour,
    edge_linewidth=0.3,
    node_size=0,
)
gdf.plot(ax=ax, fc=base3_colour, ec=None, lw=1, alpha=1, zorder=-1)
plt.title("New Zealand Southland Walking Map",color=base3_colour)
ctx.add_attribution(ax, attr_osmnx)
plt.show()
# Out:
# c:\Users\ddobs\Documents\art-of-maps-2\.venv\Lib\site-packages\osmnx\_overpass.py:267: UserWarning: This area is 26 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)

# %%
# Create Southland walking trails with matplotlib and osmnx with basemap
place ="Southland, New Zealand"
gdf = ox.geocoder.geocode_to_gdf([place])
G = ox.graph.graph_from_place(place, network_type="walk", simplify=True)
fig, ax = ox.plot.plot_graph(
    G,
    show=False,
    close=False,
    bgcolor=base3_colour,
    edge_color=green_colour,
    edge_linewidth=0.3,
    node_size=0,
)
gdf.plot(ax=ax, fc=base3_colour, ec=None, lw=1, alpha=1, zorder=-1)
plt.title("New Zealand Southland Walking Map",color=base3_colour)
ctx.add_basemap(ax)
plt.show()
# Out:
# c:\Users\ddobs\Documents\art-of-maps-2\.venv\Lib\site-packages\osmnx\_overpass.py:267: UserWarning: This area is 26 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       3 gdf = ox.geocoder.geocode_to_gdf([place])
#       4 G = ox.graph.graph_from_place(place, network_type="walk", simplify=True)
# ----> 5 fig, ax = ox.plot.plot_graph(
#       6     G,
#       7     show=False,
#       8     close=False,
#       9     bgcolor=base3_colour,
#      10     edge_color=green_colour,
#      11     edge_linewidth=0.3,
#      12     node_size=0,
#      13 )
#      14 gdf.plot(ax=ax, fc=base3_colour, ec=None, lw=1, alpha=1, zorder=-1)
#      15 plt.title("New Zealand Southland Walking Map",color=base3_colour)
#
# File c:\Users\ddobs\Documents\art-of-maps-2\.venv\Lib\site-packages\osmnx\plot.py:258, in plot_graph(G, ax, figsize, bgcolor, node_color, node_size, node_alpha, node_edgecolor, node_zorder, edge_color, edge_linewidth, edge_alpha, bbox, show, close, save, filepath, dpi)
#     255 if max_edge_lw > 0:
#     256     # plot the edges' geometries
#     257     gdf_edges = convert.graph_to_gdfs(G, nodes=False)["geometry"]
# --> 258     ax = gdf_edges.plot(ax=ax, color=edge_color, lw=edge_linewidth, alpha=edge_alpha, zorder=1)
#     260 if max_node_size > 0:
#     261     # scatter plot the nodes' x/y coordinates
#     262     gdf_nodes = convert.graph_to_gdfs(G, edges=False, node_geometry=False)[["x", "y"]]
#
# File c:\Users\ddobs\Documents\art-of-maps-2\.venv\Lib\site-packages\geopandas\geoseries.py:1019, in GeoSeries.plot(self, *args, **kwargs)
#    1017 @doc(plot_series)
#    1018 def plot(self, *args, **kwargs):
# -> 1019     return plot_series(self, *args, **kwargs)
#
# File c:\Users\ddobs\Documents\art-of-maps-2\.venv\Lib\site-packages\geopandas\plotting.py:471, in plot_series(s, cmap, color, ax, figsize, aspect, autolim, **style_kwds)
#     468     values_ = values[line_idx] if cmap else None
#     469     color_ = expl_color[line_idx] if color_given else color
# --> 471     _plot_linestring_collection(
#     472         ax, lines, values_, color=color_, cmap=cmap, autolim=autolim, **style_kwds
#     473     )
#     475 # plot all Points in the same collection
#     476 points = expl_series[point_idx]
#
# File c:\Users\ddobs\Documents\art-of-maps-2\.venv\Lib\site-packages\geopandas\plotting.py:239, in _plot_linestring_collection(ax, geoms, values, color, cmap, vmin, vmax, autolim, **kwargs)
#     235     kwargs["color"] = color
#     237 _expand_kwargs(kwargs, multiindex)
# --> 239 segments = [np.array(linestring.coords)[:, :2] for linestring in geoms]
#     240 collection = LineCollection(segments, **kwargs)
#     242 if values is not None:
#
# File c:\Users\ddobs\Documents\art-of-maps-2\.venv\Lib\site-packages\shapely\geometry\base.py:223, in BaseGeometry.coords(self)
#     221 """Access to geometry's coordinates (CoordinateSequence)."""
#     222 has_z = self.has_z
# --> 223 has_m = self.has_m if _geos_ge_312 else False
#     224 coords_array = shapely.get_coordinates(self, include_z=has_z, include_m=has_m)
#     225 return CoordinateSequence(coords_array)
#
# File c:\Users\ddobs\Documents\art-of-maps-2\.venv\Lib\site-packages\shapely\geometry\base.py:719, in BaseGeometry.has_m(self)
#     716 @property
#     717 def has_m(self):
#     718     """True if the geometry's coordinate sequence(s) have m values."""
# --> 719     return bool(shapely.has_m(self))
#
# File c:\Users\ddobs\Documents\art-of-maps-2\.venv\Lib\site-packages\shapely\decorators.py:88, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      86     for arr in array_args:
#      87         arr.flags.writeable = False
# ---> 88     return func(*args, **kwargs)
#      89 finally:
#      90     for arr, old_flag in zip(array_args, old_flags):
#
# File c:\Users\ddobs\Documents\art-of-maps-2\.venv\Lib\site-packages\shapely\predicates.py:109, in has_m(geometry, **kwargs)
#      78 @multithreading_enabled
#      79 @requires_geos("3.12.0")
#      80 def has_m(geometry, **kwargs):
#      81     """Return True if a geometry has M coordinates.
#      82
#      83     .. versionadded:: 2.1.0
#    (...)    107
#     108     """
# --> 109     return lib.has_m(geometry, **kwargs)
#
# KeyboardInterrupt:

# %%
# Create Road map of Utrecht with matplotlib and osmnx 
place ="Utrecht, Netherlands"
gdf = ox.geocoder.geocode_to_gdf([place])
G = ox.graph.graph_from_place(place, network_type="drive", retain_all=True)
fig, ax = ox.plot.plot_graph(
    G,
    show=False,
    close=False,
    bgcolor=base3_colour,
    edge_color=base03_colour,
    edge_linewidth=0.3,
    node_size=0,
)
gdf.plot(ax=ax, fc=base3_colour, ec=None, lw=1, alpha=1, zorder=-1)
plt.title("Utrecht Drive Map",color=base3_colour)
ctx.add_attribution(ax, attr_osmnx)
plt.show()

# %%
# Create Bike map of Utrecht with matplotlib and osmnx 
place ="Utrecht, Netherlands"
gdf = ox.geocoder.geocode_to_gdf([place])
G = ox.graph.graph_from_place(place, network_type="bike", retain_all=True)
fig, ax = ox.plot.plot_graph(
    G,
    show=False,
    close=False,
    bgcolor=base3_colour,
    edge_color=orange_colour,
    edge_linewidth=0.3,
    node_size=0,
)
gdf.plot(ax=ax, fc=base3_colour, ec=None, lw=1, alpha=1, zorder=-1)
plt.title("Utrecht Bike Map", color=base3_colour)
ctx.add_attribution(ax, attr_osmnx)
plt.show()
