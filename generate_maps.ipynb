# %%
import matplotlib.pyplot as plt
# import contextily as ctx
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_38932\1545037484.py in <module>
#       1 import folium
#       2 import matplotlib.pyplot as plt
# ----> 3 import contextily as ctx
#       4
#
# ModuleNotFoundError: No module named 'contextily'

# %%
# Tiles available for bike paths
#'https://tile.waymarkedtrails.org/cycling/{z}/{x}/{y}.png',attr= 'Map data: &copy; <a href="https://www.openstreetmap.org/copyright">OpenStreetMap</a> contributors | Map style: &copy; <a href="https://waymarkedtrails.org">waymarkedtrails.org</a> (<a href="https://creativecommons.org/licenses/by-sa/3.0/">CC-BY-SA</a>)')

# %%
fig, ax = plt.subplots(figsize=(5,5))
padding=0.5
ax.set_title('Netherlands Real Bike Path Network \n Data from OpenStreetMap')
ax.set_xticks([])
ax.set_yticks([])
# Out:
# []

# %%
plt.tight_layout()
map_img_path='img/netherlands_bike_paths.jpg'
plt.savefig(map_img_path,dpi=300,bbox_inches='tight',format='jpg')
